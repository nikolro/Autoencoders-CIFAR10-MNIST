# %%
# Initialize and Import Required Modules

# %%
# General Libraries
import torch
import argparse
import numpy as np
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Test cifar 121

# %%
# Import the MNIST Autoencoder file
import CIFAR10_121  

# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Define arguments
args = argparse.Namespace(
    data_path="./data",
    batch_size=128,
    latent_dim=128,
    device=device
)

# %%
#Load the Dataset and Check It

# %%
# Load dataset
train_loader, val_loader, test_loader = CIFAR10_121.load_data(args)

# Retrieve a batch of images
images_0_1, _ = next(iter(train_loader))

# Convert images to range [0,255] for proper display
images_0_255 = images_0_1 * 255  # Scale if needed

# Visualize some images
fig, axes = plt.subplots(1, 8, figsize=(12, 4))
for i in range(8):
    img = images_0_255[i].permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    img = np.clip(img, 0, 255).astype("uint8")  # Ensure valid pixel values
    axes[i].imshow(img)
    axes[i].axis("off")

plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#Verify the Autoencoder Model Architecture

# %%
# Initialize model
model = CIFAR10_121.Autoencoder(args.latent_dim).to(args.device)

# Print model summary
print(model)
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=2048, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=128, out_features=2048, bias=True)
#     (1): ReLU()
#     (2): Unflatten(dim=1, unflattened_size=(32, 8, 8))
#     (3): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): ReLU()
#     (5): ConvTranspose2d(16, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (6): Sigmoid()
#   )
# )

# %%
#Run a Single Forward Pass

# %%
# Move images to the correct device
images_0_1 = images_0_1.to(args.device)

# Pass through the autoencoder
with torch.no_grad():
    recon_images_0_1 = model(images_0_1)

# Scale back to [0,255]
recon_images_0_255 = (recon_images_0_1 * 255)

# Create the figure
fig, axes = plt.subplots(2, 8, figsize=(12, 3))
plt.subplots_adjust(wspace=0, hspace=0.1)

# Add row titles manually
fig.suptitle("Original (Top) vs Reconstructed (Bottom)", fontsize=14, y=1.05)

for i in range(8):
    # Original images
    img = images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    img = np.clip(img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[0, i].imshow(img)  
    axes[0, i].axis("off")

    # Reconstructed images
    recon_img = recon_images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    recon_img = np.clip(recon_img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[1, i].imshow(recon_img)  
    axes[1, i].axis("off")

plt.show()

# %%
#Train for One Epoch to Check Loss Computation

# %%
CIFAR10_121.train_autoencoder(model, train_loader, val_loader, args, epochs=30)
# Out:
# Epoch [1/15], Train Loss: 0.0254, Val Loss: 0.0135
# Epoch [2/15], Train Loss: 0.0115, Val Loss: 0.0103
# Epoch [3/15], Train Loss: 0.0092, Val Loss: 0.0086
# Epoch [4/15], Train Loss: 0.0081, Val Loss: 0.0076
# Epoch [5/15], Train Loss: 0.0073, Val Loss: 0.0070
# Epoch [6/15], Train Loss: 0.0067, Val Loss: 0.0063
# Epoch [7/15], Train Loss: 0.0062, Val Loss: 0.0060
# Epoch [8/15], Train Loss: 0.0059, Val Loss: 0.0058
# Epoch [9/15], Train Loss: 0.0057, Val Loss: 0.0057
# Epoch [10/15], Train Loss: 0.0055, Val Loss: 0.0055
# Epoch [11/15], Train Loss: 0.0054, Val Loss: 0.0054
# Epoch [12/15], Train Loss: 0.0054, Val Loss: 0.0054
# Epoch [13/15], Train Loss: 0.0053, Val Loss: 0.0053
# Epoch [14/15], Train Loss: 0.0053, Val Loss: 0.0053
# Epoch [15/15], Train Loss: 0.0052, Val Loss: 0.0052

# %%
#Verify Reconstruction

# %%
# Pass through the autoencoder
with torch.no_grad():
    recon_images_0_1 = model(images_0_1)

# Convert images to CPU for visualization
recon_images_0_1 = recon_images_0_1.cpu()

# Scale back to [0,255]
recon_images_0_255 = (recon_images_0_1 * 255)

# Create the figure
fig, axes = plt.subplots(2, 8, figsize=(12, 3))
plt.subplots_adjust(wspace=0, hspace=0.1)

# Add row titles manually
fig.suptitle("Original (Top) vs Reconstructed (Bottom)", fontsize=14, y=1.05)

for i in range(8):
    # Original images
    img = images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    img = np.clip(img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[0, i].imshow(img)  
    axes[0, i].axis("off")

    # Reconstructed images
    recon_img = recon_images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    recon_img = np.clip(recon_img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[1, i].imshow(recon_img)  
    axes[1, i].axis("off")

plt.show()

# %%
#classifier traning

# %%
classifier = CIFAR10_121.Classifier(args.latent_dim).to(args.device)
CIFAR10_121.train_classifier(model, classifier, train_loader, val_loader, args, epochs=15)
# Out:
# Epoch [1/15], Train Loss: 1.8731, Train Acc: 33.16%, Val Acc: 39.79%
# Epoch [2/15], Train Loss: 1.6985, Train Acc: 40.07%, Val Acc: 42.50%
# Epoch [3/15], Train Loss: 1.6365, Train Acc: 42.70%, Val Acc: 44.10%
# Epoch [4/15], Train Loss: 1.5985, Train Acc: 43.42%, Val Acc: 44.96%
# Epoch [5/15], Train Loss: 1.5721, Train Acc: 44.58%, Val Acc: 45.49%
# Epoch [6/15], Train Loss: 1.5520, Train Acc: 45.26%, Val Acc: 46.18%
# Epoch [7/15], Train Loss: 1.5387, Train Acc: 45.80%, Val Acc: 46.68%
# Epoch [8/15], Train Loss: 1.5274, Train Acc: 46.02%, Val Acc: 46.85%
# Epoch [9/15], Train Loss: 1.5147, Train Acc: 46.30%, Val Acc: 47.05%
# Epoch [10/15], Train Loss: 1.5000, Train Acc: 47.16%, Val Acc: 47.87%
# Epoch [11/15], Train Loss: 1.4946, Train Acc: 47.30%, Val Acc: 47.51%
# Epoch [12/15], Train Loss: 1.4912, Train Acc: 47.39%, Val Acc: 47.78%
# Epoch [13/15], Train Loss: 1.4829, Train Acc: 47.57%, Val Acc: 47.31%
# Epoch [14/15], Train Loss: 1.4765, Train Acc: 47.84%, Val Acc: 48.14%
# Epoch [15/15], Train Loss: 1.4685, Train Acc: 48.08%, Val Acc: 48.24%
