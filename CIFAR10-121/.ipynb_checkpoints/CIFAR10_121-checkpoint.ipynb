# %%
# Initialize and Import Required Modules

# %%
# General Libraries
import torch
import argparse
import numpy as np
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Test cifar 121

# %%
# Import the MNIST Autoencoder file
import CIFAR10_121  

# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Define arguments
args = argparse.Namespace(
    data_path="../data",
    batch_size=16,
    latent_dim=128,
    device=device
)

# %%
#Load the Dataset and Check It

# %%
# Load dataset
train_loader, val_loader, test_loader = CIFAR10_121.load_data(args)

# Retrieve a batch of images
images_0_1, _ = next(iter(train_loader))

# Convert images to range [0,255] for proper display
images_0_255 = images_0_1 * 255  # Scale if needed

# Visualize some images
fig, axes = plt.subplots(1, 8, figsize=(12, 4))
for i in range(8):
    img = images_0_255[i].permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    img = np.clip(img, 0, 255).astype("uint8")  # Ensure valid pixel values
    axes[i].imshow(img)
    axes[i].axis("off")

plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#Verify the Autoencoder Model Architecture

# %%
# Initialize model
model = CIFAR10_121.Autoencoder(args.latent_dim).to(args.device)

# Print model summary
print(model)
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=4096, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=128, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Unflatten(dim=1, unflattened_size=(256, 4, 4))
#     (3): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): ReLU()
#     (5): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (6): ReLU()
#     (7): ConvTranspose2d(64, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (8): Tanh()
#   )
# )

# %%
#Run a Single Forward Pass

# %%
# Move images to the correct device
images_0_1 = images_0_1.to(args.device)

# Pass through the autoencoder
with torch.no_grad():
    recon_images_0_1 = model(images_0_1)

# Scale back to [0,255]
recon_images_0_255 = (recon_images_0_1 * 255)

# Create the figure
fig, axes = plt.subplots(2, 8, figsize=(12, 3))
plt.subplots_adjust(wspace=0, hspace=0.1)

# Add row titles manually
fig.suptitle("Original (Top) vs Reconstructed (Bottom)", fontsize=14, y=1.05)

for i in range(8):
    # Original images
    img = images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    img = np.clip(img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[0, i].imshow(img)  
    axes[0, i].axis("off")

    # Reconstructed images
    recon_img = recon_images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    recon_img = np.clip(recon_img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[1, i].imshow(recon_img)  
    axes[1, i].axis("off")

plt.show()

# %%
#Train for One Epoch to Check Loss Computation

# %%
CIFAR10_121.train_autoencoder(model, train_loader, val_loader, args, epochs=30)
# Out:
# Epoch [1/30], Train Loss: 0.0486, Val Loss: 0.0288
# Epoch [2/30], Train Loss: 0.0251, Val Loss: 0.0224
# Epoch [3/30], Train Loss: 0.0213, Val Loss: 0.0211
# Epoch [4/30], Train Loss: 0.0199, Val Loss: 0.0202
# Epoch [5/30], Train Loss: 0.0194, Val Loss: 0.0194
# Epoch [6/30], Train Loss: 0.0190, Val Loss: 0.0193
# Epoch [7/30], Train Loss: 0.0187, Val Loss: 0.0191
# Epoch [8/30], Train Loss: 0.0185, Val Loss: 0.0191
# Epoch [9/30], Train Loss: 0.0183, Val Loss: 0.0188
# Epoch [10/30], Train Loss: 0.0181, Val Loss: 0.0188
# Epoch [11/30], Train Loss: 0.0179, Val Loss: 0.0187
# Epoch [12/30], Train Loss: 0.0178, Val Loss: 0.0188
# Epoch [13/30], Train Loss: 0.0176, Val Loss: 0.0186
# Epoch [14/30], Train Loss: 0.0175, Val Loss: 0.0187
# Epoch [15/30], Train Loss: 0.0174, Val Loss: 0.0188
# Epoch [16/30], Train Loss: 0.0173, Val Loss: 0.0188
# Epoch [17/30], Train Loss: 0.0172, Val Loss: 0.0186
# Epoch [18/30], Train Loss: 0.0171, Val Loss: 0.0186
# Epoch [19/30], Train Loss: 0.0170, Val Loss: 0.0186
# Epoch [20/30], Train Loss: 0.0169, Val Loss: 0.0186
# Epoch [21/30], Train Loss: 0.0169, Val Loss: 0.0186
# Epoch [22/30], Train Loss: 0.0168, Val Loss: 0.0187
# Epoch [23/30], Train Loss: 0.0167, Val Loss: 0.0188
# Epoch [24/30], Train Loss: 0.0167, Val Loss: 0.0187
# Epoch [25/30], Train Loss: 0.0166, Val Loss: 0.0187
# Epoch [26/30], Train Loss: 0.0165, Val Loss: 0.0188
# Epoch [27/30], Train Loss: 0.0165, Val Loss: 0.0188
# Epoch [28/30], Train Loss: 0.0164, Val Loss: 0.0188
# Epoch [29/30], Train Loss: 0.0164, Val Loss: 0.0187
# Epoch [30/30], Train Loss: 0.0163, Val Loss: 0.0188

# %%
#Verify Reconstruction

# %%
# Pass through the autoencoder
with torch.no_grad():
    recon_images_0_1 = model(images_0_1)

# Convert images to CPU for visualization
recon_images_0_1 = recon_images_0_1.cpu()

# Scale back to [0,255]
recon_images_0_255 = (recon_images_0_1 * 255)

# Create the figure
fig, axes = plt.subplots(2, 8, figsize=(12, 3))
plt.subplots_adjust(wspace=0, hspace=0.1)

# Add row titles manually
fig.suptitle("Original (Top) vs Reconstructed (Bottom)", fontsize=14, y=1.05)

for i in range(8):
    # Original images
    img = images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    img = np.clip(img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[0, i].imshow(img)  
    axes[0, i].axis("off")

    # Reconstructed images
    recon_img = recon_images_0_255[i].cpu().permute(1, 2, 0).numpy()  # Convert (C, H, W) → (H, W, C)
    recon_img = np.clip(recon_img, 0, 255).astype("uint8")  # Ensure pixel values are in valid range
    axes[1, i].imshow(recon_img)  
    axes[1, i].axis("off")

plt.show()

# %%
#classifier traning

# %%
classifier = CIFAR10_121.Classifier(args.latent_dim).to(args.device)
CIFAR10_121.train_classifier(model, classifier, train_loader, val_loader, args, epochs=20)
